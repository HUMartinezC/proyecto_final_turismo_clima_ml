# %% [markdown]
# # Hito 4 - Entrega final
#
# Este notebook sirve como índice final de entrega y defensa del proyecto hasta el hito 4.

# %% [markdown]
# ## Entregables finales
#
# - Código fuente completo en el repositorio.
# - Script único de arquitectura, ingesta y procesamiento: `scripts/run_pipeline.py`.
# - Notebooks explicativos por hito en `notebooks/`.
# - Modelos entrenados regenerables en `models/` y publicados en Hugging Face.
# - Aplicación Gradio funcional en Hugging Face Spaces.
# - Documentación técnica en `docs/`.

# %% [markdown]
# ## Mapa de documentación
#
# - `docs/problema_ml.md`: problema, target y features.
# - `docs/fuentes_datos.md`: fuentes usadas y descartadas.
# - `docs/arquitectura.md`: arquitectura de datos.
# - `docs/decisiones_tecnicas.md`: decisiones y tecnologías no implementadas.
# - `docs/eda_preparacion.md`: EDA y preparación.
# - `docs/modelado.md`: modelos y validación.
# - `docs/fine_tuning.md`: especialización costera.
# - `docs/despliegue_hf.md`: despliegue y comparación Hugging Face.

# %% [markdown]
# ## Comandos de reproducción

# %%
# !python ../scripts/run_pipeline.py --check-config
# !python ../scripts/run_pipeline.py --dry-run
# !python ../scripts/run_pipeline.py --process --skip-s3-upload
# !python ../scripts/train_export_model.py
# !python ../scripts/fine_tune_coastal_model.py

# %% [markdown]
# ## Pendientes administrativos
#
# - Crear tags o indicar commits por hito si el tribunal lo requiere.
# - Convertir el guion de presentación a diapositivas si se exige entrega en formato slide deck.
# - Commitear los cambios finales antes de cerrar la entrega.
